# %%
import os
Data_Aggregated_insurance_path=r"D:\VS Code\pulse\data\aggregated\insurance\country\india\state"
Data_Aggregated_insurance_list=os.listdir(Data_Aggregated_insurance_path)
Data_Aggregated_insurance_list
# Out:
# ['andaman-&-nicobar-islands',
#  'andhra-pradesh',
#  'arunachal-pradesh',
#  'assam',
#  'bihar',
#  'chandigarh',
#  'chhattisgarh',
#  'dadra-&-nagar-haveli-&-daman-&-diu',
#  'delhi',
#  'goa',
#  'gujarat',
#  'haryana',
#  'himachal-pradesh',
#  'jammu-&-kashmir',
#  'jharkhand',
#  'karnataka',
#  'kerala',
#  'ladakh',
#  'lakshadweep',
#  'madhya-pradesh',
#  'maharashtra',
#  'manipur',
#  'meghalaya',
#  'mizoram',
#  'nagaland',
#  'odisha',
#  'puducherry',
#  'punjab',
#  'rajasthan',
#  'sikkim',
#  'tamil-nadu',
#  'telangana',
#  'tripura',
#  'uttar-pradesh',
#  'uttarakhand',
#  'west-bengal']

# %%
pip install pandas
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.1.1 -> 25.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
for state in Data_Aggregated_insurance_list:
    years=os.listdir(f"{Data_Aggregated_insurance_path}/{state}")
    for year in years:
        quater=os.listdir(f"{Data_Aggregated_insurance_path}/{state}/{year}")
        for qtr in quater:
            print(f"{Data_Aggregated_insurance_path}/{state}/{year}/{qtr}")
# Out:
# D:\VS Code\pulse\data\aggregated\insurance\country\india\state/andaman-&-nicobar-islands/2020/2.json
# D:\VS Code\pulse\data\aggregated\insurance\country\india\state/andaman-&-nicobar-islands/2020/3.json
# D:\VS Code\pulse\data\aggregated\insurance\country\india\state/andaman-&-nicobar-islands/2020/4.json
# D:\VS Code\pulse\data\aggregated\insurance\country\india\state/andaman-&-nicobar-islands/2021/1.json
# D:\VS Code\pulse\data\aggregated\insurance\country\india\state/andaman-&-nicobar-islands/2021/2.json
# D:\VS Code\pulse\data\aggregated\insurance\country\india\state/andaman-&-nicobar-islands/2021/3.json
# D:\VS Code\pulse\data\aggregated\insurance\country\india\state/andaman-&-nicobar-islands/2021/4.json
# D:\VS Code\pulse\data\aggregated\insurance\country\india\state/andaman-&-nicobar-islands/2022/1.json
# D:\VS Code\pulse\data\aggregated\insurance\country\india\state/andaman-&-nicobar-islands/2022/2.json
# ...

# %%
pd.read_json(r'D:\VS Code\pulse\data\aggregated\insurance\country\india\state/west-bengal/2024/1.json')
# Out:
#                  success     code  \
# from                True  SUCCESS
# to                  True  SUCCESS
# transactionData     True  SUCCESS
#
#                                                               data  \
# from                                                 1704047400000
# to                                                   1711564200000
# transactionData  [{'name': 'Insurance', 'paymentInstruments': [...
#
#                  responseTimestamp
# from                 1714727757342
# to                   1714727757342
# transactionData      1714727757342

# %%
path=r"D:\VS Code\pulse\data\aggregated\insurance\country\india\state/west-bengal/2024/1.json"
with open(path,'r') as f:
    data=json.load(f)
data
# Out:
# {'success': True,
#  'code': 'SUCCESS',
#  'data': {'from': 1704047400000,
#   'to': 1711564200000,
#   'transactionData': [{'name': 'Insurance',
#     'paymentInstruments': [{'type': 'TOTAL',
#       'count': 79576,
#       'amount': 104987909.0}]}]},
#  'responseTimestamp': 1714727757342}

# %%
data.keys()
# Out:
# dict_keys(['success', 'code', 'data', 'responseTimestamp'])

# %%
data['data']
# Out:
# {'from': 1704047400000,
#  'to': 1711564200000,
#  'transactionData': [{'name': 'Insurance',
#    'paymentInstruments': [{'type': 'TOTAL',
#      'count': 79576,
#      'amount': 104987909.0}]}]}

# %%
data['data']['transactionData']
# Out:
# [{'name': 'Insurance',
#   'paymentInstruments': [{'type': 'TOTAL',
#     'count': 79576,
#     'amount': 104987909.0}]}]

# %%
#Aggregated_Insurance
import os
Aggregated_insurance_path=r"D:\VS Code\pulse\data\aggregated\insurance\country\india\state"
Aggregated_insurance_list=os.listdir(Data_Aggregated_insurance_path)
Aggregated_insurance_list
Aggregated_insurance_data={'State':[],'Year':[],'Quarter':[],'Transaction_Type':[],'Transaction_Count':[],'Transaction_Amount':[]}

for state in Aggregated_insurance_list:
    years=os.listdir(f"{Aggregated_insurance_path}/{state}")
    for year in years:
        quater=os.listdir(f"{Aggregated_insurance_path}/{state}/{year}")
        for qtr in quater:
           path=f"{Aggregated_insurance_path}/{state}/{year}/{qtr}"
           with open(path,'r') as f:
             data=json.load(f)
           for i in data['data']['transactionData']:
            Type=i['name']
            count=i['paymentInstruments'][0]['count']
            amount=i['paymentInstruments'][0]['amount']
            Data_Aggregated_insurance_data['Transaction_Type'].append(Type)
            Data_Aggregated_insurance_data['Transaction_Count'].append(count)
            Data_Aggregated_insurance_data['Transaction_Amount'].append(amount)
            Data_Aggregated_insurance_data['State'].append(state)
            Data_Aggregated_insurance_data['Year'].append(year)
            Data_Aggregated_insurance_data['Quarter'].append(int(qtr.strip('.json')))

Aggregated_insurance_dataframe=pd.DataFrame(Data_Aggregated_insurance_data)
Aggregated_insurance_dataframe
# Out:
#                           State  Year  Quarter Transaction_Type  \
# 0     andaman-&-nicobar-islands  2020        2        Insurance
# 1     andaman-&-nicobar-islands  2020        3        Insurance
# 2     andaman-&-nicobar-islands  2020        4        Insurance
# 3     andaman-&-nicobar-islands  2021        1        Insurance
# 4     andaman-&-nicobar-islands  2021        2        Insurance
# ...                         ...   ...      ...              ...
# 4769                west-bengal  2023        4        Insurance
# 4770                west-bengal  2024        1        Insurance
# 4771                west-bengal  2024        2        Insurance
# 4772                west-bengal  2024        3        Insurance
# 4773                west-bengal  2024        4        Insurance
#
#       Transaction_Count  Transaction_Amount
# 0                     6              1360.0
# 1                    41             15380.0
# 2                   124            157975.0
# ...

# %%
Aggregated_insurance_dataframe=pd.DataFrame(Data_Aggregated_insurance_data)
Aggregated_insurance_dataframe
# Out:
#                           State  Year  Quarter Transaction_Type  \
# 0     andaman-&-nicobar-islands  2020        2        Insurance
# 1     andaman-&-nicobar-islands  2020        3        Insurance
# 2     andaman-&-nicobar-islands  2020        4        Insurance
# 3     andaman-&-nicobar-islands  2021        1        Insurance
# 4     andaman-&-nicobar-islands  2021        2        Insurance
# ...                         ...   ...      ...              ...
# 4087                west-bengal  2023        4        Insurance
# 4088                west-bengal  2024        1        Insurance
# 4089                west-bengal  2024        2        Insurance
# 4090                west-bengal  2024        3        Insurance
# 4091                west-bengal  2024        4        Insurance
#
#       Transaction_Count  Transaction_Amount
# 0                     6              1360.0
# 1                    41             15380.0
# 2                   124            157975.0
# ...

# %%
import os
Aggregated_transaction_path=r"D:\VS Code\pulse\data\aggregated\transaction\country\india\state"
Aggregated_transaction_list=os.listdir(Aggregated_transaction_path)
Aggregated_transaction_list
# Out:
# ['andaman-&-nicobar-islands',
#  'andhra-pradesh',
#  'arunachal-pradesh',
#  'assam',
#  'bihar',
#  'chandigarh',
#  'chhattisgarh',
#  'dadra-&-nagar-haveli-&-daman-&-diu',
#  'delhi',
#  'goa',
#  'gujarat',
#  'haryana',
#  'himachal-pradesh',
#  'jammu-&-kashmir',
#  'jharkhand',
#  'karnataka',
#  'kerala',
#  'ladakh',
#  'lakshadweep',
#  'madhya-pradesh',
#  'maharashtra',
#  'manipur',
#  'meghalaya',
#  'mizoram',
#  'nagaland',
#  'odisha',
#  'puducherry',
#  'punjab',
#  'rajasthan',
#  'sikkim',
#  'tamil-nadu',
#  'telangana',
#  'tripura',
#  'uttar-pradesh',
#  'uttarakhand',
#  'west-bengal']

# %%
for state in Aggregated_transaction_list:
    years=os.listdir(f"{Aggregated_transaction_path}/{state}")
    for year in years:
        quater=os.listdir(f"{Aggregated_transaction_path}/{state}/{year}")
        for qtr in quater:
            print(f"{Aggregated_transaction_path}/{state}/{year}/{qtr}")
# Out:
# D:\VS Code\pulse\data\aggregated\transaction\country\india\state/andaman-&-nicobar-islands/2018/1.json
# D:\VS Code\pulse\data\aggregated\transaction\country\india\state/andaman-&-nicobar-islands/2018/2.json
# D:\VS Code\pulse\data\aggregated\transaction\country\india\state/andaman-&-nicobar-islands/2018/3.json
# D:\VS Code\pulse\data\aggregated\transaction\country\india\state/andaman-&-nicobar-islands/2018/4.json
# D:\VS Code\pulse\data\aggregated\transaction\country\india\state/andaman-&-nicobar-islands/2019/1.json
# D:\VS Code\pulse\data\aggregated\transaction\country\india\state/andaman-&-nicobar-islands/2019/2.json
# D:\VS Code\pulse\data\aggregated\transaction\country\india\state/andaman-&-nicobar-islands/2019/3.json
# D:\VS Code\pulse\data\aggregated\transaction\country\india\state/andaman-&-nicobar-islands/2019/4.json
# D:\VS Code\pulse\data\aggregated\transaction\country\india\state/andaman-&-nicobar-islands/2020/1.json
# ...

# %%
path=r"D:\VS Code\pulse\data\aggregated\transaction\country\india\state/andaman-&-nicobar-islands/2018/1.json"
with open(path,'r') as f:
    data=json.load(f)
data
# Out:
# {'success': True,
#  'code': 'SUCCESS',
#  'data': {'from': 1514745000000,
#   'to': 1522175400000,
#   'transactionData': [{'name': 'Recharge & bill payments',
#     'paymentInstruments': [{'type': 'TOTAL',
#       'count': 4200,
#       'amount': 1845307.4673655091}]},
#    {'name': 'Peer-to-peer payments',
#     'paymentInstruments': [{'type': 'TOTAL',
#       'count': 1871,
#       'amount': 12138655.299749982}]},
#    {'name': 'Merchant payments',
#     'paymentInstruments': [{'type': 'TOTAL',
#       'count': 298,
#       'amount': 452507.168646613}]},
#    {'name': 'Financial Services',
#     'paymentInstruments': [{'type': 'TOTAL',
#       'count': 33,
#       'amount': 10601.419933464953}]},
#    {'name': 'Others',
#     'paymentInstruments': [{'type': 'TOTAL',
#       'count': 256,
#       'amount': 184689.8662902223}]}]},
#  'responseTimestamp': 1630501487199}

# %%
#Agrregated_Transaction
import os
Aggregated_transaction_path=r"D:\VS Code\pulse\data\aggregated\transaction\country\india\state"
Aggregated_transaction_list=os.listdir(Aggregated_transaction_path)
Aggregated_transaction_list
Aggregated_transaction_data={'State':[],'Year':[],'Quarter':[],'Transaction_Type':[],'Transaction_Count':[],'Transaction_Amount':[]}

for state in Aggregated_transaction_list:
    years=os.listdir(f"{Aggregated_transaction_path}/{state}")
    for year in years:
        quater=os.listdir(f"{Aggregated_transaction_path}/{state}/{year}")
        for qtr in quater:
           path=f"{Aggregated_transaction_path}/{state}/{year}/{qtr}"
           with open(path,'r') as f:
             data=json.load(f)
           for i in data['data']['transactionData']:
            Type=i['name']
            count=i['paymentInstruments'][0]['count']
            amount=i['paymentInstruments'][0]['amount']
            Aggregated_transaction_data['Transaction_Type'].append(Type)
            Aggregated_transaction_data['Transaction_Count'].append(count)
            Aggregated_transaction_data['Transaction_Amount'].append(amount)
            Aggregated_transaction_data['State'].append(state)
            Aggregated_transaction_data['Year'].append(year)
            Aggregated_transaction_data['Quarter'].append(int(qtr.strip('.json')))

Aggregated_transaction_dataframe=pd.DataFrame(Aggregated_transaction_data)
Aggregated_transaction_dataframe
# Out:
#                           State  Year  Quarter          Transaction_Type  \
# 0     andaman-&-nicobar-islands  2018        1  Recharge & bill payments
# 1     andaman-&-nicobar-islands  2018        1     Peer-to-peer payments
# 2     andaman-&-nicobar-islands  2018        1         Merchant payments
# 3     andaman-&-nicobar-islands  2018        1        Financial Services
# 4     andaman-&-nicobar-islands  2018        1                    Others
# ...                         ...   ...      ...                       ...
# 5029                west-bengal  2024        4         Merchant payments
# 5030                west-bengal  2024        4     Peer-to-peer payments
# 5031                west-bengal  2024        4  Recharge & bill payments
# 5032                west-bengal  2024        4        Financial Services
# 5033                west-bengal  2024        4                    Others
#
#       Transaction_Count  Transaction_Amount
# 0                  4200        1.845307e+06
# ...

# %%
import os
Aggregated_user_path=r"D:\VS Code\pulse\data\aggregated\user\country\india\state"
Aggregated_user_list=os.listdir(Aggregated_user_path)
Aggregated_user_list
# Out:
# ['andaman-&-nicobar-islands',
#  'andhra-pradesh',
#  'arunachal-pradesh',
#  'assam',
#  'bihar',
#  'chandigarh',
#  'chhattisgarh',
#  'dadra-&-nagar-haveli-&-daman-&-diu',
#  'delhi',
#  'goa',
#  'gujarat',
#  'haryana',
#  'himachal-pradesh',
#  'jammu-&-kashmir',
#  'jharkhand',
#  'karnataka',
#  'kerala',
#  'ladakh',
#  'lakshadweep',
#  'madhya-pradesh',
#  'maharashtra',
#  'manipur',
#  'meghalaya',
#  'mizoram',
#  'nagaland',
#  'odisha',
#  'puducherry',
#  'punjab',
#  'rajasthan',
#  'sikkim',
#  'tamil-nadu',
#  'telangana',
#  'tripura',
#  'uttar-pradesh',
#  'uttarakhand',
#  'west-bengal']

# %%
for state in Aggregated_user_list:
    years=os.listdir(f"{Aggregated_user_path}/{state}")
    for year in years:
        quater=os.listdir(f"{Aggregated_user_path}/{state}/{year}")
        for qtr in quater:
            print(f"{Aggregated_user_path}/{state}/{year}/{qtr}")
# Out:
# D:\VS Code\pulse\data\aggregated\user\country\india\state/andaman-&-nicobar-islands/2018/1.json
# D:\VS Code\pulse\data\aggregated\user\country\india\state/andaman-&-nicobar-islands/2018/2.json
# D:\VS Code\pulse\data\aggregated\user\country\india\state/andaman-&-nicobar-islands/2018/3.json
# D:\VS Code\pulse\data\aggregated\user\country\india\state/andaman-&-nicobar-islands/2018/4.json
# D:\VS Code\pulse\data\aggregated\user\country\india\state/andaman-&-nicobar-islands/2019/1.json
# D:\VS Code\pulse\data\aggregated\user\country\india\state/andaman-&-nicobar-islands/2019/2.json
# D:\VS Code\pulse\data\aggregated\user\country\india\state/andaman-&-nicobar-islands/2019/3.json
# D:\VS Code\pulse\data\aggregated\user\country\india\state/andaman-&-nicobar-islands/2019/4.json
# D:\VS Code\pulse\data\aggregated\user\country\india\state/andaman-&-nicobar-islands/2020/1.json
# D:\VS Code\pulse\data\aggregated\user\country\india\state/andaman-&-nicobar-islands/2020/2.json
# ...

# %%
path=r"D:\VS Code\pulse\data\aggregated\user\country\india\state/andaman-&-nicobar-islands/2018/1.json"
with open(path,'r') as f:
    data=json.load(f)
data
# Out:
# {'success': True,
#  'code': 'SUCCESS',
#  'data': {'aggregated': {'registeredUsers': 6740, 'appOpens': 0},
#   'usersByDevice': [{'brand': 'Xiaomi',
#     'count': 1665,
#     'percentage': 0.2470326409495549},
#    {'brand': 'Samsung', 'count': 1445, 'percentage': 0.21439169139465875},
#    {'brand': 'Vivo', 'count': 982, 'percentage': 0.1456973293768546},
#    {'brand': 'Oppo', 'count': 501, 'percentage': 0.07433234421364986},
#    {'brand': 'OnePlus', 'count': 332, 'percentage': 0.04925816023738872},
#    {'brand': 'Realme', 'count': 316, 'percentage': 0.04688427299703264},
#    {'brand': 'Apple', 'count': 229, 'percentage': 0.03397626112759644},
#    {'brand': 'Motorola', 'count': 226, 'percentage': 0.03353115727002967},
#    {'brand': 'Lenovo', 'count': 202, 'percentage': 0.02997032640949555},
#    {'brand': 'Huawei', 'count': 158, 'percentage': 0.02344213649851632},
#    {'brand': 'Others', 'count': 684, 'percentage': 0.10148367952522255}]},
# ...

# %%
#Agrregated_User
import os
Aggregated_user_path=r"D:\VS Code\pulse\data\aggregated\user\country\india\state"
Aggregated_user_list=os.listdir(Aggregated_user_path)
Aggregated_user_list
Aggregated_user_data={'State':[],'Year':[],'Quarter':[],'Brand_Name':[],'Transaction_Count':[],'Transaction_Percentage':[]}

for state in Aggregated_user_list:
    years=os.listdir(f"{Aggregated_user_path}/{state}")
    for year in years:
        quater=os.listdir(f"{Aggregated_user_path}/{state}/{year}")
        for qtr in quater:
           path=f"{Aggregated_user_path}/{state}/{year}/{qtr}"
           with open(path,'r') as f:
             data=json.load(f)
           if not data['data']['usersByDevice']:
             continue
          
           for i in data['data']['usersByDevice']:
               Type=i['brand']
               count=i['count']
               amount=i['percentage']
               Aggregated_user_data['Brand_Name'].append(Type)
               Aggregated_user_data['Transaction_Count'].append(count)
               Aggregated_user_data['Transaction_Percentage'].append(amount)
               Aggregated_user_data['State'].append(state)
               Aggregated_user_data['Year'].append(year)
               Aggregated_user_data['Quarter'].append(int(qtr.strip('.json')))

Aggregated_user_dataframe=pd.DataFrame(Aggregated_user_data)
Aggregated_user_dataframe
# Out:
#                           State  Year  Quarter Brand_Name  Transaction_Count  \
# 0     andaman-&-nicobar-islands  2018        1     Xiaomi               1665
# 1     andaman-&-nicobar-islands  2018        1    Samsung               1445
# 2     andaman-&-nicobar-islands  2018        1       Vivo                982
# 3     andaman-&-nicobar-islands  2018        1       Oppo                501
# 4     andaman-&-nicobar-islands  2018        1    OnePlus                332
# ...                         ...   ...      ...        ...                ...
# 6727                west-bengal  2022        1     Lenovo             330017
# 6728                west-bengal  2022        1    Infinix             284678
# 6729                west-bengal  2022        1       Asus             280347
# 6730                west-bengal  2022        1      Apple             277752
# 6731                west-bengal  2022        1     Others            2196334
#
#       Transaction_Percentage
# ...

# %%
import os
Map_Insurance_path=r"D:\VS Code\pulse\data\map\insurance\country\india\state"
Map_Insurance_list=os.listdir(Aggregated_user_path)
for state in Map_Insurance_list:
        years=os.listdir(f"{Map_Insurance_path}/{state}")
        for year in years:
            quater=os.listdir(f"{Map_Insurance_path}/{state}/{year}")
            for qtr in quater:
                print(f"{Map_Insurance_path}/{state}/{year}/{qtr}")
# Out:
# D:\VS Code\pulse\data\map\insurance\country\india\state/andaman-&-nicobar-islands/2020/2.json
# D:\VS Code\pulse\data\map\insurance\country\india\state/andaman-&-nicobar-islands/2020/3.json
# D:\VS Code\pulse\data\map\insurance\country\india\state/andaman-&-nicobar-islands/2020/4.json
# D:\VS Code\pulse\data\map\insurance\country\india\state/andaman-&-nicobar-islands/2021/1.json
# D:\VS Code\pulse\data\map\insurance\country\india\state/andaman-&-nicobar-islands/2021/2.json
# D:\VS Code\pulse\data\map\insurance\country\india\state/andaman-&-nicobar-islands/2021/3.json
# D:\VS Code\pulse\data\map\insurance\country\india\state/andaman-&-nicobar-islands/2021/4.json
# D:\VS Code\pulse\data\map\insurance\country\india\state/andaman-&-nicobar-islands/2022/1.json
# D:\VS Code\pulse\data\map\insurance\country\india\state/andaman-&-nicobar-islands/2022/2.json
# D:\VS Code\pulse\data\map\insurance\country\india\state/andaman-&-nicobar-islands/2022/3.json
# ...

# %%
path=r"D:\VS Code\pulse\data\map\insurance\country\india\state/andaman-&-nicobar-islands/2020/2.json"
with open(path,'r') as f:
    data=json.load(f)
data
# Out:
# {'success': True,
#  'code': 'SUCCESS',
#  'data': {'meta': {'dataLevel': 'STATE',
#    'gridLevel': 11,
#    'percentiles': {'10.0': 1,
#     '20.0': 1,
#     '40.0': 2,
#     '80.0': 3,
#     '90.0': 3,
#     '99.5': 3,
#     '50.0': 2,
#     '30.0': 2,
#     '60.0': 2}},
#   'data': {'columns': ['lat', 'lng', 'metric', 'label'],
#    'data': [[9.173490186987454, 92.81284629716966, 3.0, 'nicobars district'],
#     [11.665257436858854, 92.75309356673915, 2.0, 'south andaman district'],
#     [11.665446250597826, 92.73319282403017, 1.0, 'south andaman district']]}},
#  'responseTimestamp': 1692610808552}

# %%
#Map_Insurance
import os
Map_Insurance_path=r"D:\VS Code\pulse\data\map\insurance\country\india\state"
Map_Insurance_list=os.listdir(Map_Insurance_path)
Map_Insurance_list
Map_Insurance_data={'State':[],'Year':[],'Quarter':[],'Latitude':[],'Longitude':[],'Metric':[],'District':[]}

for state in Map_Insurance_list:
    years=os.listdir(f"{Map_Insurance_path}/{state}")
    for year in years:
        quater=os.listdir(f"{Map_Insurance_path}/{state}/{year}")
        for qtr in quater:
           path=f"{Map_Insurance_path}/{state}/{year}/{qtr}"
           with open(path,'r') as f:
             data=json.load(f)
           if not data['data']['data']['data']:
             continue
           columns = data['data']['data']['columns'] 
           for i in data['data']['data']['data']:
               i = dict(zip(columns, i))
               lat=i['lat']
               long=i['lng']
               met=i['metric']
               dist=i['label']
               Map_Insurance_data['Latitude'].append(lat)
               Map_Insurance_data['Longitude'].append(long)
               Map_Insurance_data['Metric'].append(met)
               Map_Insurance_data['District'].append(dist)
               Map_Insurance_data['State'].append(state)
               Map_Insurance_data['Year'].append(year)
               Map_Insurance_data['Quarter'].append(int(qtr.strip('.json')))

Map_Insurance_dataframe=pd.DataFrame(Map_Insurance_data)
Map_Insurance_dataframe
# Out:
#                              State  Year  Quarter   Latitude  Longitude  \
# 0        andaman-&-nicobar-islands  2020        2   9.173490  92.812846
# 1        andaman-&-nicobar-islands  2020        2  11.665257  92.753094
# 2        andaman-&-nicobar-islands  2020        2  11.665446  92.733193
# 3        andaman-&-nicobar-islands  2020        3  11.653981  92.743142
# 4        andaman-&-nicobar-islands  2020        3  11.654075  92.723246
# ...                            ...   ...      ...        ...        ...
# 1043132                west-bengal  2024        4  22.522693  87.475255
# 1043133                west-bengal  2024        4  22.637723  87.226997
# 1043134                west-bengal  2024        4  23.595769  86.907310
# 1043135                west-bengal  2024        4  26.707859  89.611038
# 1043136                west-bengal  2024        4  26.754551  89.469491
#
#          Metric                    District
# 0           3.0           nicobars district
# ...

# %%
import os
Map_Insurance_hover_path=r"D:\VS Code\pulse\data\map\insurance\hover\country\india\state"
Map_Insurance_hover_list=os.listdir(Map_Insurance_hover_path)
for state in Map_Insurance_hover_list:
        years=os.listdir(f"{Map_Insurance_hover_path}/{state}")
        for year in years:
            quater=os.listdir(f"{Map_Insurance_hover_path}/{state}/{year}")
            for qtr in quater:
                print(f"{Map_Insurance_hover_path}/{state}/{year}/{qtr}")
# Out:
# D:\VS Code\pulse\data\map\insurance\hover\country\india\state/andaman-&-nicobar-islands/2020/2.json
# D:\VS Code\pulse\data\map\insurance\hover\country\india\state/andaman-&-nicobar-islands/2020/3.json
# D:\VS Code\pulse\data\map\insurance\hover\country\india\state/andaman-&-nicobar-islands/2020/4.json
# D:\VS Code\pulse\data\map\insurance\hover\country\india\state/andaman-&-nicobar-islands/2021/1.json
# D:\VS Code\pulse\data\map\insurance\hover\country\india\state/andaman-&-nicobar-islands/2021/2.json
# D:\VS Code\pulse\data\map\insurance\hover\country\india\state/andaman-&-nicobar-islands/2021/3.json
# D:\VS Code\pulse\data\map\insurance\hover\country\india\state/andaman-&-nicobar-islands/2021/4.json
# D:\VS Code\pulse\data\map\insurance\hover\country\india\state/andaman-&-nicobar-islands/2022/1.json
# D:\VS Code\pulse\data\map\insurance\hover\country\india\state/andaman-&-nicobar-islands/2022/2.json
# ...

# %%
path=r"D:\VS Code\pulse\data\map\insurance\hover\country\india\state/andaman-&-nicobar-islands/2020/2.json"
with open(path,'r') as f:
    hdata=json.load(f)
hdata
# Out:
# {'success': True,
#  'code': 'SUCCESS',
#  'data': {'hoverDataList': [{'name': 'south andaman district',
#     'metric': [{'type': 'TOTAL', 'count': 3, 'amount': 795.0}]},
#    {'name': 'nicobars district',
#     'metric': [{'type': 'TOTAL', 'count': 3, 'amount': 565.0}]}]},
#  'responseTimestamp': 1692610808730}

# %%
hdata['data']['hoverDataList']
# Out:
# [{'name': 'south andaman district',
#   'metric': [{'type': 'TOTAL', 'count': 3, 'amount': 795.0}]},
#  {'name': 'nicobars district',
#   'metric': [{'type': 'TOTAL', 'count': 3, 'amount': 565.0}]}]

# %%
#Map_Hover
import os
Map_Insurance_hover_path=r"D:\VS Code\pulse\data\map\insurance\hover\country\india\state"
Map_Insurance_hover_list=os.listdir(Map_Insurance_hover_path)
Map_Insurance_hover_list
Map_Insurance_hover_data={'State':[],'Year':[],'Quarter':[],'District':[],'Transaction_Count':[],'Transaction_Amount':[]}

for state in Map_Insurance_hover_list:
    years=os.listdir(f"{Map_Insurance_hover_path}/{state}")
    for year in years:
        quater=os.listdir(f"{Map_Insurance_hover_path}/{state}/{year}")
        for qtr in quater:
           path=f"{Map_Insurance_hover_path}/{state}/{year}/{qtr}"
           with open(path,'r') as f:
             hdata=json.load(f)
           if 'hoverDataList' not in hdata['data'] or not hdata['data']['hoverDataList']:
             continue         
           for i in hdata['data']['hoverDataList']:
               dist=i['name']
               count=i['metric'][0]['count']
               amount=i['metric'][0]['amount']
               Map_Insurance_hover_data['District'].append(dist)
               Map_Insurance_hover_data['Transaction_Count'].append(count)
               Map_Insurance_hover_data['Transaction_Amount'].append(amount)
               Map_Insurance_hover_data['State'].append(state)
               Map_Insurance_hover_data['Year'].append(year)
               Map_Insurance_hover_data['Quarter'].append(int(qtr.strip('.json')))

Map_Insurance_hover_dataframe=pd.DataFrame(Map_Insurance_hover_data)
Map_Insurance_hover_dataframe
# Out:
#                            State  Year  Quarter  \
# 0      andaman-&-nicobar-islands  2020        2
# 1      andaman-&-nicobar-islands  2020        2
# 2      andaman-&-nicobar-islands  2020        3
# 3      andaman-&-nicobar-islands  2020        3
# 4      andaman-&-nicobar-islands  2020        3
# ...                          ...   ...      ...
# 13871                west-bengal  2024        4
# 13872                west-bengal  2024        4
# 13873                west-bengal  2024        4
# 13874                west-bengal  2024        4
# 13875                west-bengal  2024        4
#
#                                 District  Transaction_Count  \
# 0                 south andaman district                  3
# 1                      nicobars district                  3
# 2      north and middle andaman district                  1
# 3                 south andaman district                 35
# 4                      nicobars district                  5
# ...

# %%
import os
Map_Transaction_path=r"D:\VS Code\pulse\data\map\transaction\hover\country\india\state"
Map_Transactio_list=os.listdir(Map_Transaction_path)
for state in Map_Transactio_list:
        years=os.listdir(f"{Map_Transaction_path}/{state}")
        for year in years:
            quater=os.listdir(f"{Map_Transaction_path}/{state}/{year}")
            for qtr in quater:
                print(f"{Map_Transaction_path}/{state}/{year}/{qtr}")
# Out:
# D:\VS Code\pulse\data\map\transaction\hover\country\india\state/andaman-&-nicobar-islands/2018/1.json
# D:\VS Code\pulse\data\map\transaction\hover\country\india\state/andaman-&-nicobar-islands/2018/2.json
# D:\VS Code\pulse\data\map\transaction\hover\country\india\state/andaman-&-nicobar-islands/2018/3.json
# D:\VS Code\pulse\data\map\transaction\hover\country\india\state/andaman-&-nicobar-islands/2018/4.json
# D:\VS Code\pulse\data\map\transaction\hover\country\india\state/andaman-&-nicobar-islands/2019/1.json
# D:\VS Code\pulse\data\map\transaction\hover\country\india\state/andaman-&-nicobar-islands/2019/2.json
# D:\VS Code\pulse\data\map\transaction\hover\country\india\state/andaman-&-nicobar-islands/2019/3.json
# D:\VS Code\pulse\data\map\transaction\hover\country\india\state/andaman-&-nicobar-islands/2019/4.json
# D:\VS Code\pulse\data\map\transaction\hover\country\india\state/andaman-&-nicobar-islands/2020/1.json
# ...

# %%
path=r"D:\VS Code\pulse\data\map\transaction\hover\country\india\state/andaman-&-nicobar-islands/2018/1.json"
with open(path,'r') as f:
    mtdata=json.load(f)
mtdata
# Out:
# {'success': True,
#  'code': 'SUCCESS',
#  'data': {'hoverDataList': [{'name': 'north and middle andaman district',
#     'metric': [{'type': 'TOTAL', 'count': 442, 'amount': 931663.0770939873}]},
#    {'name': 'south andaman district',
#     'metric': [{'type': 'TOTAL', 'count': 5688, 'amount': 12560249.34366581}]},
#    {'name': 'nicobars district',
#     'metric': [{'type': 'TOTAL',
#       'count': 528,
#       'amount': 1139848.801225994}]}]},
#  'responseTimestamp': 1630502910687}

# %%
mtdata['data']['hoverDataList'][0]
# Out:
# {'name': 'north and middle andaman district',
#  'metric': [{'type': 'TOTAL', 'count': 442, 'amount': 931663.0770939873}]}

# %%
#Map_Transaction
import os
Map_Transaction_path=r"D:\VS Code\pulse\data\map\transaction\hover\country\india\state"
Map_Transaction_list=os.listdir(Map_Transaction_path)
Map_Transaction_list
Map_Transaction_data={'State':[],'Year':[],'Quarter':[],'District':[],'Transaction_Count':[],'Transaction_Amount':[]}

for state in Map_Transaction_list:
    years=os.listdir(f"{Map_Transaction_path}/{state}")
    for year in years:
        quater=os.listdir(f"{Map_Transaction_path}/{state}/{year}")
        for qtr in quater:
           path=f"{Map_Transaction_path}/{state}/{year}/{qtr}"
           with open(path,'r') as f:
             mtdata=json.load(f)
           if 'hoverDataList' not in mtdata['data'] or not mtdata['data']['hoverDataList']:
             continue         
           for i in mtdata['data']['hoverDataList']:
               dist=i['name']
               count=i['metric'][0]['count']
               amount=i['metric'][0]['amount']
               Map_Transaction_data['District'].append(dist)
               Map_Transaction_data['Transaction_Count'].append(count)
               Map_Transaction_data['Transaction_Amount'].append(amount)
               Map_Transaction_data['State'].append(state)
               Map_Transaction_data['Year'].append(year)
               Map_Transaction_data['Quarter'].append(int(qtr.strip('.json')))

Map_Transaction_dataframe=pd.DataFrame(Map_Transaction_data)
Map_Transaction_dataframe
# Out:
#                            State  Year  Quarter  \
# 0      andaman-&-nicobar-islands  2018        1
# 1      andaman-&-nicobar-islands  2018        1
# 2      andaman-&-nicobar-islands  2018        1
# 3      andaman-&-nicobar-islands  2018        2
# 4      andaman-&-nicobar-islands  2018        2
# ...                          ...   ...      ...
# 20599                west-bengal  2024        4
# 20600                west-bengal  2024        4
# 20601                west-bengal  2024        4
# 20602                west-bengal  2024        4
# 20603                west-bengal  2024        4
#
#                                 District  Transaction_Count  \
# 0      north and middle andaman district                442
# 1                 south andaman district               5688
# 2                      nicobars district                528
# 3      north and middle andaman district                825
# 4                 south andaman district               9395
# ...

# %%
import os
Map_User_path=r"D:\VS Code\pulse\data\map\user\hover\country\india\state"
Map_User_list=os.listdir(Map_User_path)
for state in Map_User_list:
        years=os.listdir(f"{Map_User_path}/{state}")
        for year in years:
            quater=os.listdir(f"{Map_User_path}/{state}/{year}")
            for qtr in quater:
                print(f"{Map_User_path}/{state}/{year}/{qtr}")
# Out:
# D:\VS Code\pulse\data\map\user\hover\country\india\state/andaman-&-nicobar-islands/2018/1.json
# D:\VS Code\pulse\data\map\user\hover\country\india\state/andaman-&-nicobar-islands/2018/2.json
# D:\VS Code\pulse\data\map\user\hover\country\india\state/andaman-&-nicobar-islands/2018/3.json
# D:\VS Code\pulse\data\map\user\hover\country\india\state/andaman-&-nicobar-islands/2018/4.json
# D:\VS Code\pulse\data\map\user\hover\country\india\state/andaman-&-nicobar-islands/2019/1.json
# D:\VS Code\pulse\data\map\user\hover\country\india\state/andaman-&-nicobar-islands/2019/2.json
# D:\VS Code\pulse\data\map\user\hover\country\india\state/andaman-&-nicobar-islands/2019/3.json
# D:\VS Code\pulse\data\map\user\hover\country\india\state/andaman-&-nicobar-islands/2019/4.json
# D:\VS Code\pulse\data\map\user\hover\country\india\state/andaman-&-nicobar-islands/2020/1.json
# D:\VS Code\pulse\data\map\user\hover\country\india\state/andaman-&-nicobar-islands/2020/2.json
# ...

# %%
path=r"D:\VS Code\pulse\data\map\user\hover\country\india\state/west-bengal/2024/1.json"
with open(path,'r') as f:
    mudata=json.load(f)
mudata
# Out:
# {'success': True,
#  'code': 'SUCCESS',
#  'data': {'hoverData': {'south twenty four parganas district': {'registeredUsers': 2243985,
#     'appOpens': 42483611},
#    'purba bardhaman district': {'registeredUsers': 1377496,
#     'appOpens': 28024604},
#    'uttar dinajpur district': {'registeredUsers': 716736,
#     'appOpens': 31442709},
#    'kalimpong district': {'registeredUsers': 65762, 'appOpens': 11444998},
#    'murshidabad district': {'registeredUsers': 2188015, 'appOpens': 28628013},
#    'paschim medinipur district': {'registeredUsers': 1498903,
#     'appOpens': 38126856},
#    'dakshin dinajpur district': {'registeredUsers': 511007,
#     'appOpens': 21364389},
#    'jalpaiguri district': {'registeredUsers': 462801, 'appOpens': 43873728},
#    'purulia district': {'registeredUsers': 774183, 'appOpens': 63254947},
#    'north twenty four parganas district': {'registeredUsers': 4570438,
#     'appOpens': 26700160},
# ...

# %%
mudata['data']['hoverData']
# Out:
# {'south twenty four parganas district': {'registeredUsers': 2243985,
#   'appOpens': 42483611},
#  'purba bardhaman district': {'registeredUsers': 1377496,
#   'appOpens': 28024604},
#  'uttar dinajpur district': {'registeredUsers': 716736, 'appOpens': 31442709},
#  'kalimpong district': {'registeredUsers': 65762, 'appOpens': 11444998},
#  'murshidabad district': {'registeredUsers': 2188015, 'appOpens': 28628013},
#  'paschim medinipur district': {'registeredUsers': 1498903,
#   'appOpens': 38126856},
#  'dakshin dinajpur district': {'registeredUsers': 511007,
#   'appOpens': 21364389},
#  'jalpaiguri district': {'registeredUsers': 462801, 'appOpens': 43873728},
#  'purulia district': {'registeredUsers': 774183, 'appOpens': 63254947},
#  'north twenty four parganas district': {'registeredUsers': 4570438,
#   'appOpens': 26700160},
#  'bankura district': {'registeredUsers': 1129802, 'appOpens': 34724845},
#  'jhargram district': {'registeredUsers': 217964, 'appOpens': 26760062},
# ...

# %%
for i in mudata['data']['hoverData']:
    print(i)
# Out:
# north and middle andaman district
# south andaman district
# nicobars district

# %%
hoverdata=mudata['data']['hoverData']
for district in hoverdata:
    print(district)
# Out:
# south twenty four parganas district
# purba bardhaman district
# uttar dinajpur district
# kalimpong district
# murshidabad district
# paschim medinipur district
# dakshin dinajpur district
# jalpaiguri district
# purulia district
# north twenty four parganas district
# bankura district
# jhargram district
# howrah district
# hooghly district
# kolkata district
# koch bihar district
# alipurduar district
# paschim bardhaman district
# nadia district
# birbhum district
# purba medinipur district
# maldah district
# darjiling district

# %%
for district in mudata['hoverData']:
    print(district)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[200], line 1
# ----> 1 for district in mudata['hoverData']:
#       2     print(district)
#
# KeyError: 'hoverData'

# %%
#Map_user
import os
Map_User_path=r"D:\VS Code\pulse\data\map\user\hover\country\india\state"
Map_User_list=os.listdir(Map_User_path)
Map_User_list
Map_User_data={'State':[],'Year':[],'Quarter':[],'District':[],'Registered_Users':[],'App_Usage':[]}

for state in Map_Transaction_list:
    years=os.listdir(f"{Map_User_path}/{state}")
    for year in years:
        quater=os.listdir(f"{Map_User_path}/{state}/{year}")
        for qtr in quater:
           path=f"{Map_User_path}/{state}/{year}/{qtr}"
           with open(path,'r') as f:
             mudata=json.load(f)
           if 'hoverData' not in mudata['data'] or not mudata['data']['hoverData']:
             continue         
           for district, values in mudata['data']['hoverData'].items():
               users = values['registeredUsers']
               usage = values['appOpens']
               Map_User_data['District'].append(district)
               Map_User_data['Registered_Users'].append(users)
               Map_User_data['App_Usage'].append(usage)
               Map_User_data['State'].append(state)
               Map_User_data['Year'].append(year)
               Map_User_data['Quarter'].append(int(qtr.strip('.json')))

Map_User_dataframe=pd.DataFrame(Map_User_data)
Map_User_dataframe
# Out:
#                            State  Year  Quarter  \
# 0      andaman-&-nicobar-islands  2018        1
# 1      andaman-&-nicobar-islands  2018        1
# 2      andaman-&-nicobar-islands  2018        1
# 3      andaman-&-nicobar-islands  2018        2
# 4      andaman-&-nicobar-islands  2018        2
# ...                          ...   ...      ...
# 20603                west-bengal  2024        4
# 20604                west-bengal  2024        4
# 20605                west-bengal  2024        4
# 20606                west-bengal  2024        4
# 20607                west-bengal  2024        4
#
#                                 District  Registered_Users  App_Usage
# 0      north and middle andaman district               632          0
# 1                 south andaman district              5846          0
# 2                      nicobars district               262          0
# 3      north and middle andaman district               911          0
# ...

# %%
import os
Top_Insurance_path=r"D:\VS Code\pulse\data\top\insurance\country\india\state"
Top_Insurance_list=os.listdir(Top_Insurance_path)
for state in Map_User_list:
        years=os.listdir(f"{Top_Insurance_path}/{state}")
        for year in years:
            quater=os.listdir(f"{Top_Insurance_path}/{state}/{year}")
            for qtr in quater:
                print(f"{Top_Insurance_path}/{state}/{year}/{qtr}")
# Out:
# D:\VS Code\pulse\data\top\insurance\country\india\state/andaman-&-nicobar-islands/2020/2.json
# D:\VS Code\pulse\data\top\insurance\country\india\state/andaman-&-nicobar-islands/2020/3.json
# D:\VS Code\pulse\data\top\insurance\country\india\state/andaman-&-nicobar-islands/2020/4.json
# D:\VS Code\pulse\data\top\insurance\country\india\state/andaman-&-nicobar-islands/2021/1.json
# D:\VS Code\pulse\data\top\insurance\country\india\state/andaman-&-nicobar-islands/2021/2.json
# D:\VS Code\pulse\data\top\insurance\country\india\state/andaman-&-nicobar-islands/2021/3.json
# D:\VS Code\pulse\data\top\insurance\country\india\state/andaman-&-nicobar-islands/2021/4.json
# D:\VS Code\pulse\data\top\insurance\country\india\state/andaman-&-nicobar-islands/2022/1.json
# D:\VS Code\pulse\data\top\insurance\country\india\state/andaman-&-nicobar-islands/2022/2.json
# D:\VS Code\pulse\data\top\insurance\country\india\state/andaman-&-nicobar-islands/2022/3.json
# ...

# %%
path=r"D:\VS Code\pulse\data\top\insurance\country\india\state/west-bengal/2024/1.json"
with open(path,'r') as f:
    tidata=json.load(f)
tidata
# Out:
# {'success': True,
#  'code': 'SUCCESS',
#  'data': {'states': None,
#   'districts': [{'entityName': 'north twenty four parganas',
#     'metric': {'type': 'TOTAL', 'count': 14070, 'amount': 19836922.0}},
#    {'entityName': 'kolkata',
#     'metric': {'type': 'TOTAL', 'count': 12088, 'amount': 16681997.0}},
#    {'entityName': 'south twenty four parganas',
#     'metric': {'type': 'TOTAL', 'count': 5620, 'amount': 7011874.0}},
#    {'entityName': 'howrah',
#     'metric': {'type': 'TOTAL', 'count': 5260, 'amount': 6868104.0}},
#    {'entityName': 'hooghly',
#     'metric': {'type': 'TOTAL', 'count': 4470, 'amount': 5938963.0}},
#    {'entityName': 'paschim bardhaman',
#     'metric': {'type': 'TOTAL', 'count': 4414, 'amount': 6125287.0}},
#    {'entityName': 'paschim medinipur',
#     'metric': {'type': 'TOTAL', 'count': 3797, 'amount': 4800244.0}},
#    {'entityName': 'maldah',
#     'metric': {'type': 'TOTAL', 'count': 3534, 'amount': 4532095.0}},
# ...

# %%
tidata['data']
# Out:
# {'states': None,
#  'districts': [{'entityName': 'nicobars',
#    'metric': {'type': 'TOTAL', 'count': 3, 'amount': 565.0}},
#   {'entityName': 'south andaman',
#    'metric': {'type': 'TOTAL', 'count': 3, 'amount': 795.0}}],
#  'pincodes': [{'entityName': '744301',
#    'metric': {'type': 'TOTAL', 'count': 3, 'amount': 565.0}},
#   {'entityName': '744104',
#    'metric': {'type': 'TOTAL', 'count': 2, 'amount': 513.0}},
#   {'entityName': '744101',
#    'metric': {'type': 'TOTAL', 'count': 1, 'amount': 282.0}}]}

# %%
tidata['data']['districts']
# Out:
# [{'entityName': 'nicobars',
#   'metric': {'type': 'TOTAL', 'count': 3, 'amount': 565.0}},
#  {'entityName': 'south andaman',
#   'metric': {'type': 'TOTAL', 'count': 3, 'amount': 795.0}}]

# %%
#Top_Insurance
import os
Top_Insurance_path=r"D:\VS Code\pulse\data\top\insurance\country\india\state"
Top_Insurance_list=os.listdir(Top_Insurance_path)
Top_Insurance_list
Top_Insurance_data={'State':[],'Year':[],'Quarter':[],'Districts':[],'Transaction_Count':[],'Transaction_Amount':[]}

for state in Top_Insurance_list:
    years=os.listdir(f"{Top_Insurance_path}/{state}")
    for year in years:
        quater=os.listdir(f"{Top_Insurance_path}/{state}/{year}")
        for qtr in quater:
           path=f"{Top_Insurance_path}/{state}/{year}/{qtr}"
           with open(path,'r') as f:
             tidata=json.load(f)
           if tidata['data'] is None or not tidata['data']:
              continue 
           for key_name, data_list in tidata['data'].items():
               if data_list is None:
                  continue        
           for item in data_list:
               entity = item['entityName']
               count = item['metric']['count']
               amount = item['metric']['amount']
               Top_Insurance_data['Districts'].append(entity)
               Top_Insurance_data['Transaction_Count'].append(count)
               Top_Insurance_data['Transaction_Amount'].append(amount)
               Top_Insurance_data['State'].append(state)
               Top_Insurance_data['Year'].append(year)
               Top_Insurance_data['Quarter'].append(int(qtr.strip('.json')))

Top_Insurance_dataframe=pd.DataFrame(Top_Insurance_data)
Top_Insurance_dataframe
# Out:
#                           State  Year  Quarter Districts  Transaction_Count  \
# 0     andaman-&-nicobar-islands  2020        2    744301                  3
# 1     andaman-&-nicobar-islands  2020        2    744104                  2
# 2     andaman-&-nicobar-islands  2020        2    744101                  1
# 3     andaman-&-nicobar-islands  2020        3    744112                  9
# 4     andaman-&-nicobar-islands  2020        3    744105                  7
# ...                         ...   ...      ...       ...                ...
# 6663                west-bengal  2024        4    711101                713
# 6664                west-bengal  2024        4    700091                642
# 6665                west-bengal  2024        4    700150                627
# 6666                west-bengal  2024        4    700039                619
# 6667                west-bengal  2024        4    700156                574
#
#       Transaction_Amount
# 0                  565.0
# ...

# %%
import os
Top_Transaction_path=r"D:\VS Code\pulse\data\top\transaction\country\india\state"
Top_Transaction_list=os.listdir(Top_Transaction_path)
for state in Top_Transaction_list:
        years=os.listdir(f"{Top_Transaction_path}/{state}")
        for year in years:
            quater=os.listdir(f"{Top_Transaction_path}/{state}/{year}")
            for qtr in quater:
                print(f"{Top_Transaction_path}/{state}/{year}/{qtr}")
# Out:
# D:\VS Code\pulse\data\top\transaction\country\india\state/andaman-&-nicobar-islands/2018/1.json
# D:\VS Code\pulse\data\top\transaction\country\india\state/andaman-&-nicobar-islands/2018/2.json
# D:\VS Code\pulse\data\top\transaction\country\india\state/andaman-&-nicobar-islands/2018/3.json
# D:\VS Code\pulse\data\top\transaction\country\india\state/andaman-&-nicobar-islands/2018/4.json
# D:\VS Code\pulse\data\top\transaction\country\india\state/andaman-&-nicobar-islands/2019/1.json
# D:\VS Code\pulse\data\top\transaction\country\india\state/andaman-&-nicobar-islands/2019/2.json
# D:\VS Code\pulse\data\top\transaction\country\india\state/andaman-&-nicobar-islands/2019/3.json
# D:\VS Code\pulse\data\top\transaction\country\india\state/andaman-&-nicobar-islands/2019/4.json
# D:\VS Code\pulse\data\top\transaction\country\india\state/andaman-&-nicobar-islands/2020/1.json
# D:\VS Code\pulse\data\top\transaction\country\india\state/andaman-&-nicobar-islands/2020/2.json
# ...

# %%
path=r"D:\VS Code\pulse\data\top\transaction\country\india\state/andaman-&-nicobar-islands/2018/1.json"
with open(path,'r') as f:
    ttdata=json.load(f)
ttdata
# Out:
# {'success': True,
#  'code': 'SUCCESS',
#  'data': {'states': None,
#   'districts': [{'entityName': 'south andaman',
#     'metric': {'type': 'TOTAL', 'count': 5688, 'amount': 12560249.343665812}},
#    {'entityName': 'nicobars',
#     'metric': {'type': 'TOTAL', 'count': 528, 'amount': 1139848.801225994}},
#    {'entityName': 'north and middle andaman',
#     'metric': {'type': 'TOTAL', 'count': 442, 'amount': 931663.0770939873}}],
#   'pincodes': [{'entityName': '744101',
#     'metric': {'type': 'TOTAL', 'count': 1622, 'amount': 2769297.9039997994}},
#    {'entityName': '744103',
#     'metric': {'type': 'TOTAL', 'count': 1223, 'amount': 2238041.8716124697}},
#    {'entityName': '744102',
#     'metric': {'type': 'TOTAL', 'count': 969, 'amount': 3519059.937562449}},
#    {'entityName': '744105',
#     'metric': {'type': 'TOTAL', 'count': 685, 'amount': 1298560.9515503529}},
#    {'entityName': '744104',
# ...

# %%
#Top_Transaction
import os
Top_Transaction_path=r"D:\VS Code\pulse\data\top\transaction\country\india\state"
Top_Transaction_list=os.listdir(Top_Transaction_path)
Top_Transaction_list
Top_Transaction_data={'State':[],'Year':[],'Quarter':[],'Districts':[],'Transaction_Count':[],'Transaction_Amount':[]}

for state in Top_Transaction_list:
    years=os.listdir(f"{Top_Transaction_path}/{state}")
    for year in years:
        quater=os.listdir(f"{Top_Transaction_path}/{state}/{year}")
        for qtr in quater:
           path=f"{Top_Transaction_path}/{state}/{year}/{qtr}"
           with open(path,'r') as f:
             ttdata=json.load(f)
           if ttdata['data'] is None or not ttdata['data']:
              continue 
           for key_name, data_list in ttdata['data'].items():
               if data_list is None:
                  continue        
           for item in data_list:
               entity = item['entityName']
               count = item['metric']['count']
               amount = item['metric']['amount']
               Top_Transaction_data['Districts'].append(entity)
               Top_Transaction_data['Transaction_Count'].append(count)
               Top_Transaction_data['Transaction_Amount'].append(amount)
               Top_Transaction_data['State'].append(state)
               Top_Transaction_data['Year'].append(year)
               Top_Transaction_data['Quarter'].append(int(qtr.strip('.json')))

Top_Transaction_dataframe=pd.DataFrame(Top_Transaction_data)
Top_Transaction_dataframe
# Out:
#                           State  Year  Quarter Districts  Transaction_Count  \
# 0     andaman-&-nicobar-islands  2018        1    744101               1622
# 1     andaman-&-nicobar-islands  2018        1    744103               1223
# 2     andaman-&-nicobar-islands  2018        1    744102                969
# 3     andaman-&-nicobar-islands  2018        1    744105                685
# 4     andaman-&-nicobar-islands  2018        1    744104                340
# ...                         ...   ...      ...       ...                ...
# 9994                west-bengal  2024        4    711101            6753348
# 9995                west-bengal  2024        4    700059            6662715
# 9996                west-bengal  2024        4    700039            6575693
# 9997                west-bengal  2024        4    734001            6432082
# 9998                west-bengal  2024        4    733134            6313560
#
#       Transaction_Amount
# 0           2.769298e+06
# ...

# %%
import os
Top_User_path=r"D:\VS Code\pulse\data\top\user\country\india\state"
Top_User_list=os.listdir(Top_User_path)
for state in Top_User_list:
        years=os.listdir(f"{Top_User_path}/{state}")
        for year in years:
            quater=os.listdir(f"{Top_User_path}/{state}/{year}")
            for qtr in quater:
                print(f"{Top_User_path}/{state}/{year}/{qtr}")
# Out:
# D:\VS Code\pulse\data\top\user\country\india\state/andaman-&-nicobar-islands/2018/1.json
# D:\VS Code\pulse\data\top\user\country\india\state/andaman-&-nicobar-islands/2018/2.json
# D:\VS Code\pulse\data\top\user\country\india\state/andaman-&-nicobar-islands/2018/3.json
# D:\VS Code\pulse\data\top\user\country\india\state/andaman-&-nicobar-islands/2018/4.json
# D:\VS Code\pulse\data\top\user\country\india\state/andaman-&-nicobar-islands/2019/1.json
# D:\VS Code\pulse\data\top\user\country\india\state/andaman-&-nicobar-islands/2019/2.json
# D:\VS Code\pulse\data\top\user\country\india\state/andaman-&-nicobar-islands/2019/3.json
# D:\VS Code\pulse\data\top\user\country\india\state/andaman-&-nicobar-islands/2019/4.json
# D:\VS Code\pulse\data\top\user\country\india\state/andaman-&-nicobar-islands/2020/1.json
# D:\VS Code\pulse\data\top\user\country\india\state/andaman-&-nicobar-islands/2020/2.json
# ...

# %%
path=r"D:\VS Code\pulse\data\top\user\country\india\state/andaman-&-nicobar-islands/2018/1.json"
with open(path,'r') as f:
    tudata=json.load(f)
tudata
# Out:
# {'success': True,
#  'code': 'SUCCESS',
#  'data': {'states': None,
#   'districts': [{'name': 'south andaman', 'registeredUsers': 5846},
#    {'name': 'north and middle andaman', 'registeredUsers': 632},
#    {'name': 'nicobars', 'registeredUsers': 262}],
#   'pincodes': [{'name': '744103', 'registeredUsers': 1608},
#    {'name': '744101', 'registeredUsers': 1108},
#    {'name': '744105', 'registeredUsers': 1075},
#    {'name': '744102', 'registeredUsers': 1006},
#    {'name': '744104', 'registeredUsers': 272},
#    {'name': '744202', 'registeredUsers': 237},
#    {'name': '744112', 'registeredUsers': 215},
#    {'name': '744301', 'registeredUsers': 207},
#    {'name': '744107', 'registeredUsers': 196},
#    {'name': '744211', 'registeredUsers': 156}]},
#  'responseTimestamp': 1630501494546}

# %%
#Top_User
import os
Top_User_path=r"D:\VS Code\pulse\data\top\transaction\country\india\state"
Top_User_list=os.listdir(Top_User_path)
Top_User_list
Top_User_data={'State':[],'Year':[],'Quarter':[],'District_Pin':[],'Registered_Users':[]}

for state in Top_User_list:
    years=os.listdir(f"{Top_User_path}/{state}")
    for year in years:
        quater=os.listdir(f"{Top_User_path}/{state}/{year}")
        for qtr in quater:
           path=f"{Top_User_path}/{state}/{year}/{qtr}"
           with open(path,'r') as f:
             tudata=json.load(f)
           if tudata['data'] is None or not tudata['data']:
              continue 
           for key_name, data_list in tudata['data'].items():
               if data_list is None:
                  continue        
               for item in data_list:
                   Dist = item.get('name') or item.get('entityName') or 'UNKNOWN'
                   users = item.get('registeredUsers') or (item.get('metric', {}).get('count')) or 0
                   Top_User_data['District_Pin'].append(Dist)
                   Top_User_data['Registered_Users'].append(users)
                   Top_User_data['State'].append(state)
                   Top_User_data['Year'].append(year)
                   Top_User_data['Quarter'].append(int(qtr.strip('.json')))

Top_User_dataframe=pd.DataFrame(Top_User_data)
Top_User_dataframe
# Out:
#                            State  Year  Quarter              District_Pin  \
# 0      andaman-&-nicobar-islands  2018        1             south andaman
# 1      andaman-&-nicobar-islands  2018        1                  nicobars
# 2      andaman-&-nicobar-islands  2018        1  north and middle andaman
# 3      andaman-&-nicobar-islands  2018        1                    744101
# 4      andaman-&-nicobar-islands  2018        1                    744103
# ...                          ...   ...      ...                       ...
# 18290                west-bengal  2024        4                    711101
# 18291                west-bengal  2024        4                    700059
# 18292                west-bengal  2024        4                    700039
# 18293                west-bengal  2024        4                    734001
# 18294                west-bengal  2024        4                    733134
#
#        Registered_Users
# 0                  5688
# 1                   528
# ...
